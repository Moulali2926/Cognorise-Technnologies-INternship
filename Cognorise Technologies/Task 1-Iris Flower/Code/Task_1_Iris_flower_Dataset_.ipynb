# %% [markdown]
# # **COGNORISE INFO TECH INTERNSHIP-IRIS FLOWER DATASET**

# %% [markdown]
# ![Screenshot 2023-12-05 101906.png](data:image/png;base64,...)

# %% [markdown]
# **The Iris flower dataset encompasses three distinct species: setosa, versicolor,
# and virginica.**
#
# • These species are discernible through specific measurements. Imagine
# possessing measurements of Iris flowers categorized by their distinct species.
#
# • The goal is to train a machine learning model capable of learning from these
# measurements and proficiently categorizing Iris flowers into their corresponding
# species.
#
# • Employ the Iris dataset to construct a model adept at classifying Iris flowers into
# distinct species based on their sepal and petal measurements.
#
# • This dataset serves as a prevalent choice for initial classification tasks, making it
# ideal for introductory learning experiences

# %% [markdown]
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician, eugenicist, and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis.
#
# *  It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species.
#
# * Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".
#
# *  Fisher's paper was published in the journal, the Annals of Eugenics, creating controversy about the continued use of the Iris dataset for teaching statistical techniques today.
#
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.

# %% [markdown]
# This study we try to clustering Iris Dataset used Kmeans
#
# Attribute Information:
#
# 1.sepal length in cm
#
# 2.sepal width in cm
#
# 3.petal length in cm
#
# 4.petal width in cm
#
# 5.class: -- Iris Setosa -- Iris Versicolour -- Iris Virginica

# %% [markdown]
# **Importing Libraries**

# %% [markdown]
# * **pandas (imported as pd)** is used for data manipulation and analysis.
# * **numpy (imported as np)** is used for numerical computations and working with arrays.
# * **matplotlib.pyplot (imported as plt)** is used for data visualization.
# * **seaborn (imported as sns)** is another data visualization library that works well with pandas and provides a high-level interface for drawing attractive and informative statistical graphics.
# * **sklearn.cluster.KMeans** is an implementation of K-Means clustering algorithm from Scikit-Learn, used for clustering data points.
# * **sklearn.metrics.silhouette_score** is a metric used to evaluate the quality of clusters created by clustering algorithms like K-Means.
# * **sklearn.preprocessing.MinMaxScaler** is used for scaling numerical features to a specific range (usually between 0 and 1).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# The code reads the "IRIS.csv" file into a pandas DataFrame (iris) and then extracts values from the DataFrame's first four columns (index 0 to 3) into a NumPy array (x).

# %%
iris = pd.read_csv("/content/IRIS.csv")
x = iris.iloc[:, [0, 1, 2, 3]].values

# %%
# The code iris.head() is used to display the first few rows of the DataFrame named iris.
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#iris.info(): Summarizes DataFrame structure and data types.
#iris[0:10]: Displays the first ten rows of the DataFrame.
iris.info()
iris[0:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# ...

# %%
iris_outcome = pd.crosstab(index=iris["species"],  # Make a crosstab
                              columns="count")      # Name the count column

iris_outcome
# Out:
# col_0            count
# species
# Iris-setosa         50
# Iris-versicolor     50
# Iris-virginica      50

# %%
iris_setosa=iris.loc[iris["species"]=="Iris-setosa"]
iris_virginica=iris.loc[iris["species"]=="Iris-virginica"]
iris_versicolor=iris.loc[iris["species"]=="Iris-versicolor"]

# %% [markdown]
# # **MATPLOTLIB**:
# Matplotlib is a Python library for making basic to complex visualizations, enabling users to create simple or intricate plots and graphs to represent data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris  # Importing the Iris dataset

# Load the Iris dataset
iris = load_iris()
iris = sns.load_dataset("iris")  # Or load the dataset from Seaborn directly

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # 1 row, 3 columns for 3 plots

# Plot 1: petal_length
sns.histplot(data=iris, x="petal_length", hue="species", kde=True, ax=axes[0])
axes[0].set_title('Petal Length')

# Plot 2: petal_width
sns.histplot(data=iris, x="petal_width", hue="species", kde=True, ax=axes[1])
axes[1].set_title('Petal Width')

# Plot 3: sepal_length
sns.histplot(data=iris, x="sepal_length", hue="species", kde=True, ax=axes[2])
axes[2].set_title('Sepal Length')

# Add legend to the last subplot
axes[2].legend()

# Adjust layout
plt.tight_layout()

# Show the combined plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # BOXPLOT
#  A boxplot is a visual representation of numerical data that displays the distribution's key features: median, quartiles, and outliers, helping to identify the spread and central tendency of the dataset.

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
plt.show()

# %% [markdown]
# # VIOLINPLOT:
#
#
# A violin plot is a graph that combines a boxplot and a density plot. It shows the distribution of numeric data across different categories, displaying the data's probability density.

# %%
sns.violinplot(x="species",y="petal_length",data=iris)
plt.show()

# %% [markdown]
# # PAIRPLOT:
#
#
# A pairplot is a seaborn plot that shows pairwise relationships between numerical variables in a dataset through scatterplots and histograms, allowing quick exploration of correlations and distributions.

# %%
sns.set_style("whitegrid")
sns.pairplot(iris,hue="species",size=3);
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn import svm, datasets
df = datasets.load_iris()

# %% [markdown]
# # Support Vector Machine (SVM) :
# It is a powerful machine learning algorithm used for classification tasks. It finds the best possible line or boundary (hyperplane) that separates different classes in the data, aiming to maximize the margin between classes.

# %%
x = df.data

# %%
y = df.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
model = svm.SVC(kernel='rbf', C=30, gamma='auto')
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.9555555555555556

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[1, 10, 20], 'kernel':['rbf', 'linear']}
mod = GridSearchCV(svm.SVC(gamma='auto'), param_grid, cv = 5)
mod.fit(x, y)
mod.cv_results_
# Out:
# {'mean_fit_time': array([0.00300694, 0.00172596, 0.00088434, 0.00080686, 0.00123458,
#         0.00140047]),
#  'std_fit_time': array([1.10515921e-03, 1.71865674e-03, 2.26130439e-05, 3.73298023e-05,
#         5.30718245e-04, 6.21016466e-04]),
#  'mean_score_time': array([0.00203257, 0.00071158, 0.00057402, 0.00056748, 0.00067277,
#         0.00082345]),
#  'std_score_time': array([1.62592772e-03, 2.55379692e-04, 8.70485790e-06, 3.09864914e-05,
#         3.97744506e-05, 2.63338017e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
# ...

# %%
import pandas as pd
fr = pd.DataFrame(mod.cv_results_)
fr[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.973333
# 4      20          rbf         0.966667
# 5      20       linear         0.966667

# %%
mod.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {'C':[1, 10, 20], 'kernel':['rbf', 'linear']}
mor = RandomizedSearchCV(svm.SVC(gamma='auto'), param_grid, cv = 5, n_iter=2)
mor.fit(x, y)
rs = pd.DataFrame(mod.cv_results_)
rs[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.973333
# 4      20          rbf         0.966667
# 5      20       linear         0.966667

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
param_svm = {'C':[1, 10, 20], 'kernel':['rbf', 'linear']}
param_for = {'n_estimators':[1, 5, 10]}
param_log = {'C':[1, 5, 10]}

# %% [markdown]
# # Logistic Regression:
# It is a method used in machine learning for predicting binary outcomes. It determines the probability of an event by fitting data to a sigmoid curve, making it a fundamental tool for classification tasks.

# %% [markdown]
# # Random Forest:
# It is a machine learning algorithm that creates multiple decision trees and combines their predictions to make more accurate and robust predictions for both classification and regression tasks.

# %%
mod_svm = GridSearchCV(svm.SVC(gamma='auto'), param_svm, cv=5, n_jobs=3)
mod_for = GridSearchCV(RandomForestClassifier(), param_for, cv=5, n_jobs=3)
mod_log = GridSearchCV(LogisticRegression(solver='liblinear', multi_class='auto'), param_log, cv=5, n_jobs=3)

mod_svm.fit(x, y)
mod_for.fit(x, y)
mod_log.fit(x, y)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(solver='liblinear'), n_jobs=3,
#              param_grid={'C': [1, 5, 10]})

# %%
print("svm model")
print(mod_svm.best_params_)
print(mod_svm.best_score_)
# Out:
# svm model
# {'C': 1, 'kernel': 'rbf'}
# 0.9800000000000001

# %% [markdown]
# **Support Vector Machine (SVM):**
#
# * Reported Best Parameters: {'C': 1, 'kernel': 'rbf'}
# * Reported Best Score: 0.980
# * Interpretation: The SVM model achieved an accuracy score of 98.0% with the specified parameters on the dataset.
#
# This means it correctly predicted the target variable in the dataset 98% of the time.

# %%
print("random forest")
print(mod_for.best_params_)
print(mod_for.best_score_)
# Out:
# random forest
# {'n_estimators': 5}
# 0.9666666666666668

# %% [markdown]
# **Random Forest:**
#
# * Reported Best Parameters: {'n_estimators': 5}
# * Reported Best Score: 0.967
# * Interpretation: The Random Forest model achieved an accuracy score of 96.7% with 5 estimators on the dataset.
#  It correctly predicted the target variable 96.7% of the time.

# %%
print("logistic")
print(mod_log.best_params_)
print(mod_log.best_score_)
# Out:
# logistic
# {'C': 5}
# 0.9666666666666668

# %% [markdown]
# **Logistic Regression:**
#
# * Reported Best Parameters: {'C': 5}
# * Reported Best Score: 0.967
# * Interpretation: The Logistic Regression model also achieved an accuracy score of 96.7% with a regularization parameter C set to 5.
#
#  It correctly predicted the target variable 96.7% of the time.

# %% [markdown]
# # CONCLUSION:
#
#
# * The SVM model achieved the highest reported accuracy of 98.0% among the three models.
# * Both Random Forest and Logistic Regression models obtained similar accuracy scores of 96.7%.

# %% [markdown]
# Based on these reported scores, the SVM model appears to perform the best among the three models evaluated, as it has the highest reported accuracy score on the given dataset.
